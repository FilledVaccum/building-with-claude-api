# %% [markdown]
# # System Prompts

# %% [markdown]
# ## Without System Prompt

# %%
# importing necessary packages
import boto3
import json

# %%
# Creating a client 
bedrock_client = boto3.client('bedrock-runtime', region_name = 'us-west-2')

# Model ID
model_id = 'global.anthropic.claude-sonnet-4-6'

# System Prompt
system_prompt = ''

# %%
# Defining fuction to add user message

def add_user_message(messages, text):
    user_message = {
        'role' : 'user',
        'content' : [
            { 'text' : text }
        ]
    }
    messages.append(user_message)

# Function to add "Assistant" messages to the list 
def add_assistant_message(messages, text):
    assistant_message = {
        'role' : 'assistant',
        'content' : [
            { 'text' : text }
        ]
    }
    messages.append(assistant_message)

# Function to invoke the model and return the assistant response
def chat(messages):

    response = bedrock_client.converse(
        modelId = model_id,
        messages = messages
    )

    return response['output']['message']['content'][0]['text']

# %%
# Making an empty list where we will store the messages
messages = []


# Using a while True loop to run chatbot forever

while True:

    # Get User Input
    user_input = input(">")

    # add user input to messages list
    add_user_message(messages, user_input)

    # Pass the list of messages into the chat to get an answer
    assistant_response = chat(messages)  # response from chat funtion defined earlier will be saved to answer variable - this is assistant message

    # Take the answer and add it to the list - answer = assistant message
    add_assistant_message(messages, assistant_response)

    # Printing assistant reponse 
    print(assistant_response)
# Out:
# > How to setup postgresql in aws?
# # Setting Up PostgreSQL on AWS
#
# ## Option 1: Amazon RDS (Recommended - Managed Service)
#
# ### Step 1: Create RDS Instance
# ```
# AWS Console → RDS → Create Database
# ```
#
# **Configuration:**
# - **Engine:** PostgreSQL
# - **Version:** Choose latest stable (e.g., 15.x)
# - **Template:** Production / Dev-Test / Free Tier
# - **DB Instance Identifier:** my-postgres-db
# - **Master Username:** postgres (or custom)
# - **Master Password:** [strong password]
#
# ### Step 2: Instance Configuration
# ```
# Instance Class: db.t3.micro (Free Tier)
# Storage: 20 GB (gp2/gp3)
# Enable Storage Autoscaling: Yes (optional)
# ```
#
# ### Step 3: Connectivity Settings
# ```
# VPC: Default or custom VPC
# Subnet Group: Default
# Public Access: Yes (dev) / No (production)
# VPC Security Group: Create new or select existing
# Port: 5432
# ```
#
# ### Step 4: Configure Security Group
# ```
# Inbound Rules:
# - Type: PostgreSQL
# - Port: 5432
# - Source: Your IP / 0.0.0.0/0 (not recommended for prod)
# ```
#
# ### Step 5: Connect to RDS
# ```bash
# psql -h your-endpoint.rds.amazonaws.com \
#      -U postgres \
#      -d postgres \
#      -p 5432
# ```
#
# ---
#
# ## Option 2: PostgreSQL on EC2 (Manual Setup)
#
# ### Step 1: Launch EC2 Instance
# ```
# AMI: Ubuntu 22.04 or Amazon Linux 2
# Instance Type: t2.micro (Free Tier)
# Security Group: Allow port 5432, 22
# ```
#
# ### Step 2: Install PostgreSQL
# ```bash
# # Ubuntu/Debian
# sudo apt update
# sudo apt install postgresql postgresql-contrib -y
#
# # Amazon Linux / CentOS
# sudo yum install postgresql15 postgresql15-server -y
# sudo postgresql-setup initdb
# ```
#
# ### Step 3: Start PostgreSQL
# ```bash
# sudo systemctl start postgresql
# sudo systemctl enable postgresql
# sudo systemctl status postgresql
# ```
#
# ### Step 4: Configure PostgreSQL
# ```bash
# # Switch to postgres user
# sudo -i -u postgres
# psql
#
# # Set password
# ALTER USER postgres PASSWORD 'your_password';
#
# # Create new database
# CREATE DATABASE mydb;
#
# # Create new user
# CREATE USER myuser WITH PASSWORD 'mypassword';
# GRANT ALL PRIVILEGES ON DATABASE mydb TO myuser;
# \q
# ```
#
# ### Step 5: Allow Remote Connections
# ```bash
# # Edit postgresql.conf
# sudo nano /etc/postgresql/15/main/postgresql.conf
# # Change: listen_addresses = '*'
#
# # Edit pg_hba.conf
# sudo nano /etc/postgresql/15/main/pg_hba.conf
# # Add: host all all 0.0.0.0/0 md5
#
# # Restart PostgreSQL
# sudo systemctl restart postgresql
# ```
#
# ---
#
# ## Option 3: Aurora PostgreSQL (Enterprise)
# ```
# RDS → Create Database → Amazon Aurora
# Engine: Aurora PostgreSQL Compatible
# ```
# **Benefits:** Auto-scaling, high availability, 5x performance
#
# ---
#
# ## Connection String Examples
#
# ```bash
# # Standard
# postgresql://username:password@host:5432/database
#
# # Python (psycopg2)
# conn = psycopg2.connect(
#     host="your-endpoint.rds.amazonaws.com",
#     database="mydb",
#     user="postgres",
#     password="password"
# )
#
# # Node.js
# const pool = new Pool({
#   host: 'your-endpoint.rds.amazonaws.com',
#   database: 'mydb',
#   user: 'postgres',
#   password: 'password',
#   port: 5432,
# })
# ```
#
# ---
#
# ## Best Practices
#
# | Practice | Description |
# |----------|-------------|
# | **Security** | Never expose port 5432 publicly in production |
# | **Backups** | Enable automated backups in RDS |
# | **Encryption** | Enable encryption at rest |
# | **VPC** | Use private subnets for production |
# | **IAM Auth** | Use IAM authentication instead of passwords |
# | **SSL** | Always use SSL connections |
#
# ---
#
# ## Quick Comparison
#
# | Feature | RDS | EC2 |
# |---------|-----|-----|
# | Management | AWS Managed | Self-managed |
# | Cost | Higher | Lower |
# | Maintenance | Automatic | Manual |
# | Scalability | Easy | Complex |
# | Best For | Production | Custom configs |
#
# ---
#
# **Need help with a specific setup or configuration?** Let me know your use case!
# > how to bake a bread?
# # How to Bake a Bread 🍞
#
# ## Ingredients
#
# | Ingredient | Amount |
# |------------|--------|
# | All-purpose flour | 3 cups (360g) |
# | Warm water | 1 cup (240ml) |
# | Active dry yeast | 2¼ tsp (1 packet) |
# | Salt | 1½ tsp |
# | Sugar | 1 tbsp |
# | Olive oil / butter | 2 tbsp |
#
# ---
#
# ## Equipment Needed
# - Large mixing bowl
# - Loaf pan (9x5 inch)
# - Kitchen towel or plastic wrap
# - Oven
# - Measuring cups & spoons
#
# ---
#
# ## Step-by-Step Instructions
#
# ### Step 1: Activate Yeast
# ```
# 1. Mix warm water (110°F/43°C) + sugar
# 2. Add yeast
# 3. Wait 5-10 minutes until foamy
# ```
# > ⚠️ If not foamy, yeast is dead - start over!
#
# ### Step 2: Make the Dough
# ```
# 1. Combine flour + salt in large bowl
# 2. Add yeast mixture + oil
# 3. Mix until dough forms
# ```
#
# ### Step 3: Knead the Dough
# ```
# 1. Place dough on floured surface
# 2. Knead for 8-10 minutes
# 3. Dough should be smooth & elastic
# ```
# > 💡 Tip: Dough is ready when it springs back when poked
#
# ### Step 4: First Rise
# ```
# 1. Place dough in oiled bowl
# 2. Cover with towel
# 3. Let rise for 1-2 hours
# 4. Should double in size
# ```
#
# ### Step 5: Shape the Dough
# ```
# 1. Punch down risen dough
# 2. Shape into a loaf
# 3. Place in greased loaf pan
# ```
#
# ### Step 6: Second Rise
# ```
# 1. Cover with towel
# 2. Let rise 30-45 minutes
# 3. Should rise above pan edge
# ```
#
# ### Step 7: Bake
# ```
# Temperature: 375°F (190°C)
# Time: 25-30 minutes
# Until: Golden brown on top
# ```
#
# ### Step 8: Check if Done
# ```
# 1. Tap bottom of loaf
# 2. Should sound hollow
# 3. Internal temp: 190-200°F (88-93°C)
# ```
#
# ### Step 9: Cool Down
# ```
# 1. Remove from pan
# 2. Cool on wire rack
# 3. Wait 30 minutes before cutting
# ```
# > ⚠️ Don't cut too early - bread is still cooking inside!
#
# ---
#
# ## Common Mistakes to Avoid
#
# | Mistake | Solution |
# |---------|----------|
# | Yeast not activating | Check water temperature (not too hot/cold) |
# | Dense bread | Knead more, let rise longer |
# | Crust too hard | Cover with foil last 10 mins |
# | Bread not rising | Warm environment needed (75-80°F) |
# | Gummy inside | Bake longer, check temperature |
#
# ---
#
# ## Tips for Perfect Bread 💡
#
# - ✅ Use **warm** (not hot) water
# - ✅ Knead **thoroughly**
# - ✅ Be **patient** with rising
# - ✅ Preheat oven **fully**
# - ✅ Let cool **completely**
# - ❌ Don't rush the process
# - ❌ Don't add too much flour
#
# ---
#
# ## Variations
#
# | Type | Change |
# |------|--------|
# | **Garlic Bread** | Add garlic powder + herbs |
# | **Whole Wheat** | Replace half flour with wheat flour |
# | **Sweet Bread** | Add more sugar + milk instead of water |
# | **Cheese Bread** | Add shredded cheese to dough |
#
# ---
#
# **Total Time:** ~3-4 hours
# **Difficulty:** ⭐⭐ Beginner-Friendly
#
# > 🍞 **Happy Baking!** Practice makes perfect!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 10
#       5 # Using a while True loop to run chatbot forever
#       7 while True:
#       8
#       9     # Get User Input
# ---> 10     user_input = input(">")
#      12     # add user input to messages list
#      13     add_user_message(messages, user_input)
#
# File /opt/conda/lib/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File /opt/conda/lib/python3.12/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## With System Prompts

# %%
# Creating a client 
bedrock_client = boto3.client('bedrock-runtime', region_name = 'us-west-2')

# Model ID
model_id = 'global.anthropic.claude-sonnet-4-6'

# System Prompt
system_prompt = """
You are an AWS cloud support specialist. Your job is to answer user queries related 
to cloud hosting services on AWS.
"""

# %%
# Defining fuction to add user message

def add_user_message(messages, text):
    user_message = {
        'role' : 'user',
        'content' : [
            { 'text' : text }
        ]
    }
    messages.append(user_message)

# Function to add "Assistant" messages to the list 
def add_assistant_message(messages, text):
    assistant_message = {
        'role' : 'assistant',
        'content' : [
            { 'text' : text }
        ]
    }
    messages.append(assistant_message)

# Function to invoke the model and return the assistant response
def chat(messages):

    response = bedrock_client.converse(
        modelId = model_id,
        messages = messages,
        system = [ { 'text' : system_prompt } ] # Adding System Prompt
    )

    return response['output']['message']['content'][0]['text']

# %%
# Making an empty list where we will store the messages
messages = []


# Using a while True loop to run chatbot forever

while True:

    # Get User Input
    user_input = input(">")

    # add user input to messages list
    add_user_message(messages, user_input)

    # Pass the list of messages into the chat to get an answer
    assistant_response = chat(messages)  # response from chat funtion defined earlier will be saved to answer variable - this is assistant message

    # Take the answer and add it to the list - answer = assistant message
    add_assistant_message(messages, assistant_response)

    # Printing assistant reponse 
    print(assistant_response)
# Out:
# > How to set up RDS in aws?
# # Setting Up Amazon RDS on AWS
#
# ## Prerequisites
# - An AWS account
# - Appropriate IAM permissions
# - A VPC (Virtual Private Cloud) configured
#
# ---
#
# ## Step-by-Step Setup
#
# ### Step 1: Navigate to RDS Console
# 1. Log in to **AWS Management Console**
# 2. Search for **"RDS"** in the search bar
# 3. Click **"Create database"**
#
# ---
#
# ### Step 2: Choose a Database Creation Method
# - ✅ **Standard Create** *(recommended - more control)*
# - **Easy Create** *(quick setup with defaults)*
#
# ---
#
# ### Step 3: Select Database Engine
# Choose from:
# | Engine | Best For |
# |--------|----------|
# | **MySQL** | General web apps |
# | **PostgreSQL** | Complex queries |
# | **MariaDB** | MySQL alternative |
# | **Oracle** | Enterprise apps |
# | **SQL Server** | Microsoft stack |
# | **Aurora** | High performance/scalability |
#
# ---
#
# ### Step 4: Choose a Template
# - **Production** – High availability, Multi-AZ
# - **Dev/Test** – Lower cost
# - **Free Tier** – Testing/learning
#
# ---
#
# ### Step 5: Configure Settings
# ```
# DB Instance Identifier: my-database
# Master Username: admin
# Master Password: ************
# ```
#
# ---
#
# ### Step 6: Choose Instance Size
# - **Free Tier:** `db.t3.micro`
# - **Production:** `db.t3.medium` or higher
#
# ---
#
# ### Step 7: Configure Storage
# - **Storage Type:** GP2 or GP3 (SSD)
# - **Allocated Storage:** 20 GB minimum
# - ✅ Enable **Auto Scaling** (recommended)
#
# ---
#
# ### Step 8: Connectivity Settings
# ```
# VPC: Select your VPC
# Subnet Group: Create or select existing
# Public Access: No (recommended for security)
# VPC Security Group: Create new or existing
# Port: 3306 (MySQL) / 5432 (PostgreSQL)
# ```
#
# ---
#
# ### Step 9: Additional Configuration
# - **DB Name:** my_database
# - **Backup Retention:** 7 days (recommended)
# - ✅ Enable **Encryption**
# - ✅ Enable **CloudWatch Logs**
# - ✅ Enable **Minor version auto upgrade**
#
# ---
#
# ### Step 10: Create the Database
# - Review all settings
# - Click **"Create Database"**
# - ⏳ Wait **5-10 minutes** for provisioning
#
# ---
#
# ## Connecting to Your RDS Instance
#
# ### Get Connection Details
# 1. Go to **RDS Console → Databases**
# 2. Click your database
# 3. Copy the **Endpoint URL**
#
# ### Connect via MySQL Client
# ```bash
# mysql -h your-endpoint.rds.amazonaws.com \
#       -u admin \
#       -p \
#       -P 3306
# ```
#
# ### Connect via PostgreSQL
# ```bash
# psql -h your-endpoint.rds.amazonaws.com \
#      -U admin \
#      -d my_database \
#      -p 5432
# ```
#
# ---
#
# ## Security Best Practices
#
# | Practice | Recommendation |
# |----------|---------------|
# | 🔒 Public Access | **Disable** it |
# | 🔐 Encryption | **Enable** at rest |
# | 🛡️ Security Groups | Allow only **specific IPs/ports** |
# | 👤 IAM Auth | Use instead of passwords |
# | 💾 Backups | Enable **automated backups** |
# | 🌍 Multi-AZ | Enable for **production** |
#
# ---
#
# ## Cost Optimization Tips
# - 💡 Use **Free Tier** (`db.t3.micro`) for testing
# - 💡 Use **Reserved Instances** for production (up to 60% savings)
# - 💡 **Stop** dev databases when not in use
# - 💡 Choose **GP3** over GP2 for better cost efficiency
#
# ---
#
# ## Need Help?
# Feel free to ask about:
# - **Specific database engines**
# - **Multi-AZ setup**
# - **RDS Aurora configuration**
# - **Security group configuration**
# - **RDS Proxy setup**
# > How to bake poha?
# # Sorry, I Can't Help With That! 🚫
#
# As an **AWS Cloud Support Specialist**, I'm only equipped to answer questions related to **AWS cloud hosting services**.
#
# **Baking/Cooking recipes** are outside my area of expertise.
#
# ---
#
# ## I Can Help You With:
#
# | AWS Services | Topics |
# |-------------|--------|
# | ☁️ **EC2** | Virtual machines, instances |
# | 🗄️ **RDS** | Managed databases |
# | 🪣 **S3** | Object storage |
# | 🔒 **IAM** | Security & access management |
# | 🌐 **VPC** | Networking |
# | ⚡ **Lambda** | Serverless computing |
# | 📊 **CloudWatch** | Monitoring & logging |
# | 🚀 **ECS/EKS** | Container services |
#
# ---
#
# ## Try Asking Me:
# - *"How to set up an EC2 instance?"*
# - *"How to configure S3 bucket policies?"*
# - *"How to set up Auto Scaling?"*
# - *"How to secure my AWS infrastructure?"*
#
# Feel free to ask any **AWS-related questions!** 😊

# %% [markdown]
# ### Important Technical Details
#
# When working with system prompts, keep these requirements in mind:
#
# * System prompts cannot be empty strings - they must contain at least one character
# * The system parameter expects a list of dictionaries with "text" keys
# * System prompts are processed before any user messages in the conversation
# * You can update the system prompt between conversations, but not mid-conversation
#
# System prompts give you powerful control over AI behavior without complex rule systems. By assigning Claude a specific professional role, you get consistent, appropriate responses that naturally follow the constraints and expertise of that role.
# Downloads
